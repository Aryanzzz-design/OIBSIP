# %% [markdown]
# ## Train and Evaluate Random Forest Classifier

# %% [markdown]
# **Reasoning**:
# First, I need to import the `RandomForestClassifier` from `sklearn.ensemble` and `accuracy_score`, `classification_report` from `sklearn.metrics` to train and evaluate the model.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

print("RandomForestClassifier, accuracy_score, and classification_report imported.")
# Out:
# RandomForestClassifier, accuracy_score, and classification_report imported.

# %% [markdown]
# **Reasoning**:
# Now, I will initialize the Random Forest Classifier, train it on the training data, make predictions on the test data, and evaluate its performance.

# %%
model_rf = RandomForestClassifier(random_state=42)
model_rf.fit(X_train, y_train)
y_pred_rf = model_rf.predict(X_test)

accuracy_rf = accuracy_score(y_test, y_pred_rf)
report_rf = classification_report(y_test, y_pred_rf)

print(f"Random Forest Classifier Accuracy: {accuracy_rf:.4f}")
print("\nRandom Forest Classifier Classification Report:")
print(report_rf)
# Out:
# Random Forest Classifier Accuracy: 0.7031
#
# Random Forest Classifier Classification Report:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.72      0.80      0.76        96
#            6       0.68      0.67      0.67        99
#            7       0.72      0.69      0.71        26
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.70       229
#    macro avg       0.42      0.43      0.43       229
# weighted avg       0.68      0.70      0.69       229
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ## Train and Evaluate Support Vector Classifier
#
# ### Subtask:
# Initialize a Support Vector Classifier (SVC), train it on the training data, make predictions on the test data, and evaluate its performance using accuracy and classification report. Note: SVC can be computationally intensive, consider a linear SVC if performance is an issue.

# %% [markdown]
# **Reasoning**:
# The first step for the 'Train and Evaluate Support Vector Classifier' subtask is to import the necessary modules, which includes `SVC` and evaluation metrics if they haven't been imported already.

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

print("SVC, accuracy_score, and classification_report imported.")
# Out:
# SVC, accuracy_score, and classification_report imported.

# %% [markdown]
# **Reasoning**:
# Now, I will initialize the Support Vector Classifier, train it, make predictions, and evaluate its performance.

# %%
model_svc = SVC(random_state=42)
model_svc.fit(X_train, y_train)
y_pred_svc = model_svc.predict(X_test)

accuracy_svc = accuracy_score(y_test, y_pred_svc)
report_svc = classification_report(y_test, y_pred_svc)

print(f"Support Vector Classifier Accuracy: {accuracy_svc:.4f}")
print("\nSupport Vector Classifier Classification Report:")
print(report_svc)
# Out:
# Support Vector Classifier Accuracy: 0.5633
#
# Support Vector Classifier Classification Report:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.73      0.43      0.54        96
#            6       0.51      0.88      0.64        99
#            7       1.00      0.04      0.07        26
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.56       229
#    macro avg       0.45      0.27      0.25       229
# weighted avg       0.64      0.56      0.51       229
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ## Train and Evaluate Stochastic Gradient Descent Classifier
#
# ### Subtask:
# Initialize a Stochastic Gradient Descent (SGD) Classifier, train it on the training data, make predictions on the test data, and evaluate its performance using accuracy and classification report.

# %% [markdown]
# **Reasoning**:
# The first step for the 'Train and Evaluate Stochastic Gradient Descent Classifier' subtask is to import the necessary modules. This includes the `SGDClassifier` and evaluation metrics if they haven't been imported already.

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report

print("SGDClassifier, accuracy_score, and classification_report imported.")
# Out:
# SGDClassifier, accuracy_score, and classification_report imported.

# %% [markdown]
# **Reasoning**:
# Now, I'll initialize the Stochastic Gradient Descent Classifier, train it on the training data, make predictions on the test data, and evaluate its performance.

# %%
model_sgd = SGDClassifier(random_state=42)
model_sgd.fit(X_train, y_train)
y_pred_sgd = model_sgd.predict(X_test)

accuracy_sgd = accuracy_score(y_test, y_pred_sgd)
report_sgd = classification_report(y_test, y_pred_sgd)

print(f"Stochastic Gradient Descent Classifier Accuracy: {accuracy_sgd:.4f}")
print("\nStochastic Gradient Descent Classifier Classification Report:")
print(report_sgd)
# Out:
# Stochastic Gradient Descent Classifier Accuracy: 0.4585
#
# Stochastic Gradient Descent Classifier Classification Report:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.46      0.98      0.63        96
#            6       0.56      0.05      0.09        99
#            7       0.38      0.23      0.29        26
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.46       229
#    macro avg       0.28      0.25      0.20       229
# weighted avg       0.48      0.46      0.34       229
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ## Compare Model Performances
#
# ### Subtask:
# Visualize and compare the performance metrics (accuracy, precision, recall, f1-score) of the Random Forest, Stochastic Gradient Descent, and Support Vector Classifiers to identify the best model. This step should include a visualization, such as a bar chart, to clearly show the comparison.

# %% [markdown]
# **Reasoning**:
# To compare the models effectively, I will now gather the accuracy scores of all three trained models (Random Forest, Stochastic Gradient Descent, and Support Vector Classifier) and visualize them using a bar chart for a clear comparison.

# %%
import matplotlib.pyplot as plt

accuracies = {
    'Random Forest': accuracy_rf,
    'Stochastic Gradient Descent': accuracy_sgd,
    'Support Vector Classifier': accuracy_svc
}

models = list(accuracies.keys())
scores = list(accuracies.values())

plt.figure(figsize=(12, 6))
plt.bar(models, scores, color=['skyblue', 'lightcoral', 'lightgreen'])
plt.xlabel('Classifier')
plt.ylabel('Accuracy')
plt.title('Comparison of Classifier Accuracies')
plt.ylim(0, 1)

for i, score in enumerate(scores):
    plt.text(i, score + 0.02, f'{score:.4f}', ha='center')

plt.show()
print("Accuracies for all three models compared successfully.")
# Out:
# Accuracies for all three models compared successfully.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the findings from the model comparison and identify the best-performing model for predicting wine quality based on the evaluation metrics.

# %% [markdown]
# **Reasoning**:
# Based on the accuracy scores and classification reports for all three models, I will now provide a summary of their performance and identify the best model.

# %%
best_model = max(accuracies, key=accuracies.get)
best_accuracy = accuracies[best_model]

print(f"### Model Performance Summary\n")
print(f"- **Random Forest Classifier**: Accuracy = {accuracy_rf:.4f}\n{report_rf}\n")
print(f"- **Stochastic Gradient Descent Classifier**: Accuracy = {accuracy_sgd:.4f}\n{report_sgd}\n")
print(f"- **Support Vector Classifier**: Accuracy = {accuracy_svc:.4f}\n{report_svc}\n")

print(f"**Conclusion**: The **{best_model}** has the highest accuracy of {best_accuracy:.4f} and is identified as the best-performing model for predicting wine quality based on the given dataset and evaluation metrics. While all models faced challenges with minority classes (as indicated by the UndefinedMetricWarning for classes 4 and 8), the Random Forest Classifier demonstrated superior overall performance.")
# Out:
# ### Model Performance Summary
#
# - **Random Forest Classifier**: Accuracy = 0.7031
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.72      0.80      0.76        96
#            6       0.68      0.67      0.67        99
#            7       0.72      0.69      0.71        26
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.70       229
#    macro avg       0.42      0.43      0.43       229
# weighted avg       0.68      0.70      0.69       229
#
#
# - **Stochastic Gradient Descent Classifier**: Accuracy = 0.4585
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.46      0.98      0.63        96
#            6       0.56      0.05      0.09        99
#            7       0.38      0.23      0.29        26
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get all feature columns except the 'quality' target column
feature_columns = [col for col in df.columns if col != 'quality']

# Set up the matplotlib figure layout
plt.figure(figsize=(20, 25))

# Loop through each feature to create a box plot
for i, column in enumerate(feature_columns, 1):
    plt.subplot(6, 2, i) # Adjust subplot grid as needed based on number of features
    sns.boxplot(x='quality', y=column, data=df, palette='viridis')
    plt.title(f'Distribution of {column} by Wine Quality')
    plt.xlabel('Wine Quality')
    plt.ylabel(column)

plt.tight_layout()
plt.show()

print("Box plots for each feature grouped by wine quality have been generated.")
# Out:
# /tmp/ipykernel_1330/4272013062.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality', y=column, data=df, palette='viridis')
# /tmp/ipykernel_1330/4272013062.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality', y=column, data=df, palette='viridis')
# /tmp/ipykernel_1330/4272013062.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality', y=column, data=df, palette='viridis')
# /tmp/ipykernel_1330/4272013062.py:13: FutureWarning:
#
# ...

# %% [markdown]
# **CONCLUSION**

# %% [markdown]
# the Random Forest Classifier is the best-performing model among the three evaluated, demonstrating the highest accuracy of 0.7031 in predicting wine quality. The exploratory data analysis further highlighted specific chemical characteristics that are strong indicators of wine quality, which likely contributed to the Random Forest model's superior performance. While challenges with minority classes were noted, the Random Forest model provides a strong foundation for future predictions on this dataset. Further efforts could involve addressing class imbalance or exploring more advanced ensemble techniques to improve predictions for these challenging quality levels.
